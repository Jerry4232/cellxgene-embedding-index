# %% [markdown]
# Dataset link
#
# https://chanzuckerberg.github.io/cellxgene-census/notebooks/api_demo/census_datasets.html
#
# Pub Med link
#
# https://pubmed.ncbi.nlm.nih.gov/

# %%
import cellxgene_census

census = cellxgene_census.open_soma(census_version="2025-01-30")
census_datasets = census["census_info"]["datasets"].read().concat().to_pandas()

# for convenience, indexing on the soma_joinid which links this to other census data.
census_datasets = census_datasets.set_index("soma_joinid")

census_datasets.head()
# Out:
#                                                       citation  \
# soma_joinid
# 0            Publication: https://doi.org/10.1016/j.isci.20...
# 1            Publication: https://doi.org/10.1016/j.isci.20...
# 2            Publication: https://doi.org/10.1016/j.isci.20...
# 3            Publication: https://doi.org/10.1016/j.isci.20...
# 4            Publication: https://doi.org/10.1038/s41591-02...
#
#                                     collection_id  \
# soma_joinid
# 0            8e880741-bf9a-4c8e-9227-934204631d2a
# 1            8e880741-bf9a-4c8e-9227-934204631d2a
# 2            8e880741-bf9a-4c8e-9227-934204631d2a
# 3            8e880741-bf9a-4c8e-9227-934204631d2a
# 4            a96133de-e951-4e2d-ace6-59db8b3bfb1d
#
#                                                collection_name  \
# soma_joinid
# 0            High Resolution Slide-seqV2 Spatial Transcript...
# 1            High Resolution Slide-seqV2 Spatial Transcript...
# 2            High Resolution Slide-seqV2 Spatial Transcript...
# 3            High Resolution Slide-seqV2 Spatial Transcript...
# 4            HTAN/HTAPP Broad - Spatio-molecular dissection...
#
#                          collection_doi              collection_doi_label  \
# soma_joinid
# 0            10.1016/j.isci.2022.104097   Marshall et al. (2022) iScience
# 1            10.1016/j.isci.2022.104097   Marshall et al. (2022) iScience
# 2            10.1016/j.isci.2022.104097   Marshall et al. (2022) iScience
# 3            10.1016/j.isci.2022.104097   Marshall et al. (2022) iScience
# 4            10.1038/s41591-024-03215-z  Klughammer et al. (2024) Nat Med
#
#                                        dataset_id  \
# soma_joinid
# 0            4eb29386-de81-452f-b3c0-e00844e8c7fd
# 1            78d59e4a-82eb-4a61-a1dc-da974d7ea54b
# 2            add5eb84-5fc9-4f01-982e-a346dd42ee82
# 3            b020294c-ab82-4547-b5a7-63d8ffa575ed
# 4            d7476ae2-e320-4703-8304-da5c42627e71
#
#                                dataset_version_id  \
# soma_joinid
# 0            f76861bb-becb-4eb7-82fc-782dc96ccc7f
# 1            7d7ec1b6-6e3f-4aaa-9442-4b22f3424396
# 2            de54aed8-4f73-48f6-9229-418a840e2d82
# 3            abe4fce1-0859-4a56-ad1e-734d79f0e6c8
# 4            863fc5e4-bd4a-4681-9c3d-0ee7ef54e327
#
#                                                 dataset_title  \
# soma_joinid
# 0            Spatial transcriptomics in mouse: Puck_191112_05
# 1            Spatial transcriptomics in mouse: Puck_191112_08
# 2            Spatial transcriptomics in mouse: Puck_191109_20
# 3            Spatial transcriptomics in mouse: Puck_191112_13
# 4                                HTAPP-330-SMP-1082 scRNA-seq
#
#                                      dataset_h5ad_path  \
# soma_joinid
# 0            4eb29386-de81-452f-b3c0-e00844e8c7fd.h5ad
# 1            78d59e4a-82eb-4a61-a1dc-da974d7ea54b.h5ad
# 2            add5eb84-5fc9-4f01-982e-a346dd42ee82.h5ad
# 3            b020294c-ab82-4547-b5a7-63d8ffa575ed.h5ad
# 4            d7476ae2-e320-4703-8304-da5c42627e71.h5ad
#
#              dataset_total_cell_count
# soma_joinid
# 0                               10888
# 1                               10250
# 2                               12906
# 3                               15161
# 4                                 565

# %%
import re
doi_links: list[tuple[int, str]] = []
for i in range(len(census_datasets)):
    text = census_datasets.loc[i, "citation"]
    match = re.search(r'Publication:\s*https?://doi.org/(\S+)', text)
    if match:
        doi_links.append((i, match.group(1)))

print(f"Found {len(doi_links)} publication DOIs.")

import pandas as pd
duplicate_doi_series = pd.Series(dict(doi_links))
doi_series = duplicate_doi_series[~duplicate_doi_series.duplicated(keep='first')]
print(f"Found {len(doi_series)} unique publication DOIs.")
doi_series.head(10)
# Out:
# Found 1558 publication DOIs.
# Found 236 unique publication DOIs.
# 0     10.1016/j.isci.2022.104097
# 4     10.1038/s41591-024-03215-z
# 6              10.1002/hep4.1854
# 7     10.1038/s41586-024-07944-6
# 9     10.1126/sciimmunol.abe6291
# 13    10.1038/s41588-023-01435-6
# 18    10.1038/s41593-020-00764-7
# 21     10.1101/2024.09.10.612293
# 22    10.1038/s41467-022-29450-x
# 24    10.1038/s41590-021-01059-0
# dtype: object

# %%
import os
import csv

# Constants
OUTPUT_CSV = "methods_sections.csv"
EMAIL = "test@example.com"
CSV_FIELDS = ["soma_joinid", "doi", "title", "method_headers"]
if not os.path.exists(OUTPUT_CSV):
    with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=CSV_FIELDS)
        writer.writeheader()

# %%
import requests
from bs4 import BeautifulSoup
import time
import json

def get_pmcid_from_doi(doi: str) -> str | None:
    url = f"https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/?tool=test&email={EMAIL}&ids={doi}"
    resp = requests.get(url)
    # time.sleep(1.5)
    soup = BeautifulSoup(resp.text, "xml")
    return soup.find("record").get("pmcid")

def fetch_pmc_xml(pmcid: str) -> BeautifulSoup:
    xml_url = f"https://www.ncbi.nlm.nih.gov/pmc/oai/oai.cgi?verb=GetRecord&identifier=oai:pubmedcentral.nih.gov:{pmcid[3:]}&metadataPrefix=pmc"
    resp = requests.get(xml_url)
    # time.sleep(1.5)
    return BeautifulSoup(resp.content, "xml")

def extract_article_title(xml_soup: BeautifulSoup) -> str | None:
    # PubMed format
    alt_title = xml_soup.find("ArticleTitle")
    if alt_title:
        return alt_title.get_text(strip=True)
    
    # PMC full-text format
    article_title = xml_soup.find("article-title")
    if article_title:
        return article_title.get_text(strip=True)

    return None

def extract_methods_headers_only(xml_soup: BeautifulSoup) -> list[str]:
    methods_sec: list[str] = [
        sec for sec in xml_soup.find("body").find_all("sec", recursive=False)
        if sec.find("title") and "method" in sec.find("title").get_text(strip=True).lower()
    ]
    if len(methods_sec) == 0:
        return []
    if len(methods_sec) > 1:
        print("Warning: Multiple methods sections found, using the first one.")

    method = methods_sec[0]
    headers = []
    for sub_sec in method.find_all("sec", recursive=False):
        title = sub_sec.find("title")
        if title:
            headers.append(title.get_text(strip=True))
    return headers

def append_headers_to_csv(path: str, records: list[dict], write_header: bool = False):
    with open(path, "a", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["soma_joinid", "doi", "title", "method_headers"])
        if write_header:
            writer.writeheader()
        for row in records:
            row["method_headers"] = json.dumps(row["method_headers"], ensure_ascii=False)
            row["title"] = row["title"].strip().replace("\n", " ").replace("\r", " ")  # clean up line breaks
            writer.writerow(row)

# %%
import pandas as pd

written_df = pd.read_csv(OUTPUT_CSV)
written_set = set(zip(written_df["soma_joinid"], written_df["doi"]))

# Lists to track rows with missing info
no_pmcid_list = []
no_title_list = []
no_headers_list = []

for idx, doi in doi_series.items():
    if (idx, doi) in written_set:
        print(f"Row {idx} - Already processed.")
        continue

    try:
        pmcid = get_pmcid_from_doi(doi)
        if not pmcid:
            print(f"Row {idx} - No PMCID for DOI {doi}")
            no_pmcid_list.append(idx)
            continue

        xml_soup = fetch_pmc_xml(pmcid)

        title = extract_article_title(xml_soup)
        if not title:
            print(f"Row {idx} - No title found.")
            no_title_list.append(idx)
            continue

        headers = extract_methods_headers_only(xml_soup)
        if not headers:
            print(f"Row {idx} - No valid Methods section found.")
            no_headers_list.append(idx)
            continue

        record = [{
            "soma_joinid": idx,
            "doi": doi,
            "title": title,
            "method_headers": headers
        }]

        append_headers_to_csv(OUTPUT_CSV, record, write_header=False)
        print(f"Row {idx} - Wrote {len(headers)} headers, for '{title[:50]}...'")
    except Exception as e:
        print(f"Row {idx} - Error: {e}")
# Out:
# Row 0 - Wrote 5 headers, for 'High-resolution Slide-seqV2 spatial transcriptomic...'
# Row 4 - Wrote 32 headers, for 'A multi-modal single-cell and spatial expression m...'
# Row 6 - Wrote 8 headers, for 'Single‐Cell, Single‐Nucleus, and Spatial RNA Seque...'
# Row 7 - Wrote 34 headers, for 'A spatial human thymus cell atlas mapped to a cont...'
# Row 9 - No PMCID for DOI 10.1126/sciimmunol.abe6291
# Row 13 - Wrote 17 headers, for 'Spatiotemporal transcriptomic maps of whole mouse ...'
# Row 18 - Wrote 15 headers, for 'Molecular characterization of selectively vulnerab...'
# Row 21 - No title found.
# Row 22 - Wrote 20 headers, for 'Single-cell Atlas of common variable immunodeficie...'
# Row 24 - Wrote 22 headers, for 'Single-cell proteo-genomic reference maps of the h...'
# Row 26 - No title found.
# Row 31 - No PMCID for DOI 10.1016/j.celrep.2019.12.082
# Row 40 - No PMCID for DOI 10.1016/j.cell.2022.11.005
# Row 51 - No PMCID for DOI 10.1016/j.jhep.2023.12.023
# Row 74 - Wrote 5 headers, for 'Longitudinal profiling of respiratory and systemic...'
# Row 75 - No title found.
# Row 95 - Wrote 5 headers, for 'A Cellular Anatomy of the Normal Adult Human Prost...'
# Row 97 - No title found.
# Row 106 - No PMCID for DOI 10.1126/science.adf1226
# Row 114 - No PMCID for DOI 10.1158/2159-8290.cd-22-0824
# Row 119 - Wrote 6 headers, for 'Cell Atlas of The Human Fovea and Peripheral Retin...'
# Row 121 - Wrote 4 headers, for 'Differential cell composition and split epidermal ...'
# Row 136 - Wrote 24 headers, for 'Profiling the heterogeneity of colorectal cancer c...'
# Row 153 - No title found.
# Row 159 - Wrote 32 headers, for 'Cells of the adult human heart...'
# Row 175 - Wrote 4 headers, for 'An interactive single cell web portal identifies g...'
# Row 179 - No valid Methods section found.
# Row 188 - Wrote 25 headers, for 'Spatial multiomics map of trophoblast development ...'
# Row 194 - Wrote 17 headers, for 'Immune microniches shape intestinal Tregfunction...'
# Row 198 - Wrote 6 headers, for 'Spatiotemporal analysis of human intestinal develo...'
# Row 214 - No title found.
# Row 235 - No PMCID for DOI 10.1101/2022.02.18.481097
# Row 246 - No title found.
# Row 254 - No title found.
# Row 255 - Wrote 23 headers, for 'Brain matters: unveiling the distinct contribution...'
# Row 262 - No title found.
# Row 272 - Wrote 13 headers, for 'Integrated multimodal cell atlas of Alzheimer’s di...'
# Row 275 - No PMCID for DOI 10.1126/science.add7046
# Row 280 - No valid Methods section found.
# Row 282 - Wrote 4 headers, for 'Exploring the utility of snRNA-seq in profiling hu...'
# Row 283 - Wrote 5 headers, for 'Charting human development using a multi-endoderma...'
# Row 288 - Wrote 3 headers, for 'A spatially resolved atlas of the human lung chara...'
# Row 294 - Wrote 12 headers, for 'Deciphering glial contributions to CSF1R-related d...'
# Row 302 - Wrote 7 headers, for 'Smoking modulates different secretory subpopulatio...'
# Row 304 - No title found.
# Row 307 - Wrote 4 headers, for 'Single-cell analyses of renal cell cancers reveal ...'
# Row 308 - Wrote 6 headers, for 'A Single-Cell Transcriptome Atlas of the Human Pan...'
# Row 328 - No title found.
# Row 330 - Wrote 18 headers, for 'Altered human oligodendrocyte heterogeneity in mul...'
# Row 331 - No title found.
# Row 334 - Wrote 8 headers, for 'Inflammation-mediated fibroblast activation and im...'
# Row 343 - Wrote 9 headers, for 'Single-Cell Transcriptomic Profiling Identifies Mo...'
# Row 349 - Wrote 25 headers, for 'Spatially resolved multiomics of human cardiac nic...'
# Row 360 - Wrote 4 headers, for 'Single-cell transcriptomics of the human retinal p...'
# Row 371 - Wrote 12 headers, for 'Single-cell transcriptomic atlas of the human reti...'
# Row 381 - Wrote 8 headers, for 'A single-cell atlas of the aging mouse ovary...'
# Row 386 - Wrote 19 headers, for 'Single-cell transcriptome analysis reveals differe...'
# Row 387 - No title found.
# Row 399 - Wrote 15 headers, for 'A single-cell time-lapse of mouse prenatal develop...'
# Row 402 - Wrote 4 headers, for 'Cellular atlas of the human ovary using morphologi...'
# Row 407 - Wrote 6 headers, for 'Conserved transcriptional connectivity of regulato...'
# Row 413 - No PMCID for DOI 10.1101/2021.09.16.460628
# Row 417 - Wrote 9 headers, for 'Single cell RNA sequencing of human liver reveals ...'
# Row 428 - Wrote 13 headers, for 'High‐resolution single‐cell transcriptomic survey ...'
# Row 436 - No title found.
# Row 447 - No title found.
# Row 451 - Wrote 6 headers, for 'Single cell derived mRNA signals across human kidn...'
# Row 471 - Wrote 18 headers, for 'A transcriptional cross species map of pancreatic ...'
# Row 472 - No title found.
# Row 476 - No title found.
# Row 486 - Wrote 15 headers, for 'CD8+T cells induce interferon-responsive oligodend...'
# Row 489 - No PMCID for DOI 10.1096/fj.202300601RRR
# Row 493 - Wrote 1 headers, for 'Multiscale spatial mapping of cell populations acr...'
# Row 494 - Wrote 12 headers, for 'Single-cell mapping reveals new markers and functi...'
# Row 496 - No PMCID for DOI 10.3389/fdmed.2021.806294
# Row 498 - Wrote 23 headers, for 'Single cell RNA sequencing of human microglia unco...'
# Row 501 - Wrote 30 headers, for 'Single-cell genomic profiling of human dopamine ne...'
# Row 505 - Wrote 7 headers, for 'Single-cell transcriptomes of the human skin revea...'
# Row 513 - Wrote 9 headers, for 'Single-cell reconstruction of follicular remodelin...'
# Row 519 - Wrote 22 headers, for 'Comparative cellular analysis of motor cortex in h...'
# Row 534 - Wrote 8 headers, for 'Persistent T cell unresponsiveness associated with...'
# Row 537 - Wrote 5 headers, for 'mRNA COVID-19 vaccine elicits potent adaptive immu...'
# Row 542 - Wrote 8 headers, for 'Mapping the developing human immune system across ...'
# Row 546 - Wrote 4 headers, for 'Single‐cell RNA sequencing captures patient‐level ...'
# Row 557 - Wrote 16 headers, for 'Stress-induced RNA–chromatin interactions promote ...'
# Row 560 - Wrote 32 headers, for 'Spatial multi-omic map of human myocardial infarct...'
# Row 565 - No title found.
# Row 573 - No title found.
# Warning: Multiple methods sections found, using the first one.
# Row 591 - Wrote 1 headers, for 'Adult Mouse Cortical Cell Taxonomy by Single Cell ...'
# Row 594 - Wrote 18 headers, for 'Phenotypic variation of transcriptomic cell types ...'
# Row 596 - Wrote 3 headers, for 'SARS‐CoV‐2 receptorACE2 andTMPRSS2 are primarily e...'
# Row 602 - Wrote 3 headers, for 'Human skeletal muscle aging atlas...'
# Row 608 - Wrote 5 headers, for 'Mapping single-cell transcriptomes in the intra-tu...'
# Row 610 - Wrote 4 headers, for 'Differential pre-malignant programs and microenvir...'
# Row 617 - No title found.
# Row 621 - Wrote 16 headers, for 'A single-cell atlas enables mapping of homeostatic...'
# Row 628 - No PMCID for DOI 10.1101/2024.11.01.621259
# Row 633 - Wrote 25 headers, for 'The single-cell transcriptomic atlas iPain identif...'
# Row 635 - Wrote 25 headers, for 'A human embryonic limb cell atlas resolved in spac...'
# Row 641 - Wrote 7 headers, for 'Early role for a Na+,K+-ATPase (ATP1A3) in brain d...'
# Row 642 - Wrote 3 headers, for 'Single-cell multiomics reveals increased plasticit...'
# Row 650 - Wrote 21 headers, for 'Single cell transcriptional and chromatin accessib...'
# Row 659 - No PMCID for DOI 10.1101/2023.09.04.555678
# Row 682 - No PMCID for DOI 10.1101/2021.03.28.437379
# Row 685 - No title found.
# Row 706 - Wrote 22 headers, for 'Single-cell roadmap of human gonadal development...'
# Row 710 - Wrote 3 headers, for 'Single-cell transcriptomics reveals gene expressio...'
# Row 725 - Wrote 12 headers, for 'A transcriptomic and epigenomic cell atlas of the ...'
# Warning: Multiple methods sections found, using the first one.
# Row 728 - Wrote 9 headers, for 'A molecular cell atlas of the human lung from sing...'
# Row 729 - Wrote 2 headers, for 'Cell atlas of the human ocular anterior segment: T...'
# Row 731 - Wrote 14 headers, for 'Early human lung immune cell development and its r...'
# Row 737 - Wrote 3 headers, for 'Ovarian cancer mutational processes drive site-spe...'
# Row 741 - No title found.
# Row 744 - No title found.
# Row 747 - Wrote 6 headers, for 'Spatial proteogenomics reveals distinct and evolut...'
# Row 754 - No title found.
# Row 765 - No PMCID for DOI 10.1038/s41591-018-0269-2
# Row 767 - Wrote 17 headers, for 'Mapping the temporal and spatial dynamics of the h...'
# Row 769 - No PMCID for DOI 10.1101/2024.01.23.576878
# Row 771 - Wrote 6 headers, for 'Single‐cell transcriptomic analysis of gingivo‐buc...'
# Row 772 - Wrote 14 headers, for 'A Single-Cell Transcriptional Roadmap of the Mouse...'
# Row 779 - Wrote 6 headers, for 'Single-Cell Sequencing of Developing Human Gut Rev...'
# Row 788 - No title found.
# Row 790 - No title found.
# Row 799 - Wrote 4 headers, for 'A molecular atlas of the human postmenopausal fall...'
# Row 804 - No title found.
# Row 816 - No title found.
# Row 817 - No title found.
# Row 829 - Wrote 5 headers, for 'Cell Types of the Human Retina and Its Organoids a...'
# Row 842 - Wrote 10 headers, for 'Single-cell RNA-Seq analysis reveals cell subsets ...'
# Row 849 - No title found.
# Row 851 - No PMCID for DOI 10.1016/j.celrep.2024.114247
# Row 860 - Wrote 5 headers, for 'Impaired local intrinsic immunity to SARS-CoV-2 in...'
# Row 862 - Wrote 8 headers, for 'Human photoreceptor cells from different macular s...'
# Row 871 - Wrote 19 headers, for 'Immunophenotyping of COVID-19 and influenza highli...'
# Row 873 - Wrote 20 headers, for 'Distinct microbial and immune niches of the human
# ...'
# Row 876 - No title found.
# Row 893 - Wrote 16 headers, for 'Single-cell transcriptomics of human T cells revea...'
# Row 897 - No title found.
# Row 899 - No title found.
# Row 904 - No PMCID for DOI 10.1101/2024.03.05.583423
# Row 906 - No PMCID for DOI 10.1101/2021.09.17.21263540
# Row 910 - No title found.
# Row 925 - No valid Methods section found.
# Row 938 - Wrote 18 headers, for 'Single-cell multiomic profiling of human lungs rev...'
# Row 939 - Wrote 5 headers, for 'A single-cell atlas of the healthy breast tissues ...'
# Row 948 - Wrote 11 headers, for 'Multiomic profiling of human clonal hematopoiesis ...'
# Row 958 - No valid Methods section found.
# Row 968 - Wrote 26 headers, for 'Generation of complex bone marrow organoids from h...'
# Row 980 - No PMCID for DOI 10.1101/2020.11.20.20227355
# Row 987 - Wrote 5 headers, for 'A multi-omics atlas of the human retina at single-...'
# Row 998 - Wrote 16 headers, for 'Multimodal single cell sequencing implicates chrom...'
# Row 1012 - Wrote 6 headers, for 'scRNA-seq assessment of the human lung, spleen, an...'
# Row 1014 - Wrote 14 headers, for 'A single-cell comparison of adult and fetal human ...'
# Row 1028 - Wrote 5 headers, for 'Comprehensive single-cell atlas of the mouse retin...'
# Row 1051 - No title found.
# Row 1053 - Wrote 6 headers, for 'Single-cell profiling of healthy human kidney reve...'
# Row 1064 - Wrote 4 headers, for 'Cellular and transcriptional diversity over the co...'
# Row 1065 - Wrote 17 headers, for 'Single-cell genomics improves the discovery of ris...'
# Row 1073 - Wrote 4 headers, for 'Cross-tissue immune cell analysis reveals tissue-s...'
# Row 1076 - Wrote 14 headers, for 'Single-cell transcriptome profiling of the human d...'
# Row 1086 - No title found.
# Row 1103 - Wrote 13 headers, for 'Spatial and cell-type transcriptional landscape of...'
# Row 1120 - Wrote 7 headers, for 'Transcriptomic Analysis of Air–Liquid Interface Cu...'
# Row 1138 - No PMCID for DOI 10.1016/j.cell.2023.11.026
# Row 1140 - No PMCID for DOI 10.1101/2023.11.07.566105
# Row 1148 - Wrote 3 headers, for 'A comprehensive mouse kidney atlas enables rare ce...'
# Row 1155 - Wrote 5 headers, for 'Prolonged cytopenia following CD19 CAR T cell ther...'
# Row 1157 - Wrote 12 headers, for 'Transcriptional profiles of murine oligodendrocyte...'
# Row 1161 - Wrote 6 headers, for 'Single-cell and spatially resolved interactomics o...'
# Row 1173 - No title found.
# Row 1182 - No title found.
# Row 1183 - Wrote 13 headers, for 'Follicular Lymphoma Microenvironment Characteristi...'
# Row 1200 - No PMCID for DOI 10.1016/j.immuni.2020.03.019
# Row 1203 - No title found.
# Row 1208 - Wrote 16 headers, for 'Identification of distinct tumor cell populations ...'
# Row 1213 - Wrote 13 headers, for 'Sex-Specific Control of Human Heart Maturation by ...'
# Row 1216 - Wrote 16 headers, for 'Single-cell multi-omics analysis of human pancreat...'
# Row 1220 - No PMCID for DOI 10.1165/rcmb.2021-0555OC
# Row 1224 - No PMCID for DOI 10.1101/2024.06.18.599579
# Row 1227 - Wrote 16 headers, for 'Single nuclei transcriptomics in human and non-hum...'
# Row 1229 - Wrote 21 headers, for 'Interstitial macrophages are a focus of viral take...'
# Row 1244 - Wrote 6 headers, for 'Time-resolved systems immunology reveals a late ju...'
# Row 1246 - No title found.
# Row 1249 - No title found.
# Row 1261 - No PMCID for DOI 10.1016/j.coi.2022.102188
# Row 1264 - No PMCID for DOI 10.1016/j.stem.2023.12.013
# Row 1267 - Wrote 17 headers, for 'Molecular Signatures of Resilience to Alzheimer’s ...'
# Row 1276 - No PMCID for DOI 10.1016/j.ajt.2024.08.019
# Row 1291 - No title found.
# Row 1292 - Wrote 12 headers, for 'Cryptic exon detection and transcriptomic changes ...'
# Row 1297 - No title found.
# Row 1301 - No title found.
# Row 1312 - No PMCID for DOI 10.1038/s41586-020-2157-4
# Row 1315 - No title found.
# Row 1322 - Wrote 16 headers, for 'Single-cell multiomic analysis of thymocyte develo...'
# Row 1324 - Wrote 12 headers, for 'Coordinated immune dysregulation in juvenile derma...'
# Row 1326 - No title found.
# Row 1341 - Wrote 37 headers, for 'An atlas of healthy and injured cell states and ni...'
# Row 1346 - Wrote 5 headers, for 'Transcriptomic and spatial dissection of humanex v...'
# Row 1350 - No PMCID for DOI 10.1038/s41591-021-01586-1
# Row 1351 - Wrote 10 headers, for 'A Proximal-to-Distal Survey of Healthy Adult Human...'
# Row 1369 - Wrote 4 headers, for 'Thyroid hormone remodels cortex to coordinate body...'
# Row 1380 - No PMCID for DOI 10.1101/2024.09.11.612431
# Row 1383 - No title found.
# Row 1389 - Wrote 2 headers, for 'Single-cell transcriptional mapping reveals geneti...'
# Row 1397 - Wrote 19 headers, for 'Cross-species single-cell RNA-seq analysis reveals...'
# Row 1402 - No PMCID for DOI 10.1101/2020.03.04.976407
# Row 1413 - Wrote 5 headers, for 'Molecular and spatial signatures of mouse brain ag...'
# Row 1427 - Wrote 5 headers, for 'Integrated analysis of multimodal single-cell data...'
# Row 1435 - No PMCID for DOI 10.1101/2023.11.20.567825
# Row 1446 - Wrote 7 headers, for 'Integrated cancer cell-specific single-cell RNA-se...'
# Row 1467 - Wrote 12 headers, for 'Local and systemic responses to SARS-CoV-2 infecti...'
# Row 1473 - No title found.
# Row 1480 - Wrote 15 headers, for 'HypoMap—a unified single-cell gene expression atla...'
# Row 1485 - Wrote 24 headers, for 'Delineating mouse β-cell identity during lifetime ...'
# Row 1487 - Wrote 16 headers, for 'Guided construction of single cell reference for h...'
# Row 1488 - No PMCID for DOI 10.1016/j.cels.2024.04.002
# Row 1489 - No PMCID for DOI 10.1126/science.abf3041
# Row 1498 - No title found.
# Row 1502 - No title found.
# Row 1504 - Wrote 5 headers, for 'A blood atlas of COVID-19 defines hallmarks of dis...'
# Row 1507 - Wrote 29 headers, for 'Cells of the human intestinal tract mapped across ...'
# Row 1508 - No title found.
# Row 1509 - Wrote 35 headers, for 'An integrated cell atlas of the lung in health and...'
# Row 1511 - Wrote 17 headers, for 'Type I interferon autoantibodies are associated wi...'
# Row 1514 - Wrote 17 headers, for 'An atlas of cortical arealization identifies dynam...'
# Row 1517 - Wrote 35 headers, for 'Single-cell multi-omics analysis of the immune res...'
# Row 1527 - No title found.
# Row 1529 - No PMCID for DOI 10.1101/2022.08.27.505439
# Row 1536 - No PMCID for DOI 10.1101/2024.06.30.601119
# Row 1541 - No title found.
# Row 1545 - Wrote 6 headers, for 'High-resolution single-cell atlas reveals diversit...'
# Row 1547 - Wrote 5 headers, for 'COVID-19 immune features revealed by a large-scale...'
# Row 1551 - Wrote 25 headers, for 'An integrated transcriptomic cell atlas of human n...'
# Row 1561 - Wrote 3 headers, for 'A multi-region single nucleus transcriptomic atlas...'

# %%
# remove duplicates with method headers

import pandas as pd
df = pd.read_csv(OUTPUT_CSV, dtype={"soma_joinid": int, "doi": str, "title": str, "method_headers": str})
print(df[["soma_joinid", "doi", "title", "method_headers"]].head())
# Out:
#    soma_joinid                         doi  \
# 0            0  10.1016/j.isci.2022.104097
# 1            4  10.1038/s41591-024-03215-z
# 2            6           10.1002/hep4.1854
# 3            7  10.1038/s41586-024-07944-6
# 4           13  10.1038/s41588-023-01435-6
#
#                                                title  \
# 0  High-resolution Slide-seqV2 spatial transcript...
# 1  A multi-modal single-cell and spatial expressi...
# 2  Single‐Cell, Single‐Nucleus, and Spatial RNA S...
# 3  A spatial human thymus cell atlas mapped to a ...
# 4  Spatiotemporal transcriptomic maps of whole mo...
#
#                                       method_headers
# 0  ["Key resources table", "Resource availability...
# 1  ["Ethics statement", "Sample acquisition, hand...
# 2  ["Preparation of Fresh Tissue Homogenates and ...
# 3  ["Data generation by institute", "Sample proce...
# 4  ["Animal work and embryo preparation (WT and K...

# %%
# bad dataset table with reason not working

bad_indices = sorted(set(no_pmcid_list + no_title_list + no_headers_list))
df_filtered = census_datasets.loc[bad_indices]
"""
['citation', 'collection_id', 'collection_name', 'collection_doi',
       'collection_doi_label', 'dataset_id', 'dataset_version_id',
       'dataset_title', 'dataset_h5ad_path', 'dataset_total_cell_count']"""
# df_filtered[["collection_doi", "dataset_title"]].head(20)

# Create mapping from index to label
labels = {}

# if sec.find("title") and "method" in sec.find("title").get_text(strip=True).lower()
# xml_soup.find("body").find_all("sec", recursive=False)
# method = methods_sec[0]
# method.find_all("sec", recursive=False)

for i in no_pmcid_list:
    labels[i] = "no_pmcid"
for i in no_title_list:
    labels[i] = "no_title"
for i in no_headers_list:
    labels[i] = "no_method_headers"

# Convert to DataFrame with the same index
issue_labels = pd.Series(labels, name="issue_type")

# Join with the filtered dataset
df_filtered = census_datasets.loc[bad_indices].copy()
df_filtered["issue_type"] = issue_labels
df_filtered[["collection_doi", "dataset_title", "issue_type"]].head(20)
# Out:
#                            collection_doi  \
# soma_joinid
# 9              10.1126/sciimmunol.abe6291
# 21              10.1101/2024.09.10.612293
# 26           10.1016/j.immuni.2022.09.002
# 31           10.1016/j.celrep.2019.12.082
# 40             10.1016/j.cell.2022.11.005
# 51             10.1016/j.jhep.2023.12.023
# 75                     10.1002/pros.24020
# 97             10.1038/s41588-021-00911-1
# 106               10.1126/science.adf1226
# 114          10.1158/2159-8290.cd-22-0824
# 153             10.1038/s41586-020-2496-1
# 179           10.21203/rs.3.rs-3601404/v2
# 214            10.1016/j.cell.2017.09.004
# 235             10.1101/2022.02.18.481097
# 246             10.1101/2024.12.01.626279
# 254               10.1126/science.adf2359
# 262          10.1016/j.celrep.2017.10.030
# 275               10.1126/science.add7046
# 280               10.1126/science.abo1984
# 304               10.1126/science.aat5031
#
#                                                  dataset_title  \
# soma_joinid
# 9                         Human tonsil nonlymphoid cells scRNA
# 21                               slide-seqV2 analysis of aorta
# 26                            Normal Spleen OT1 Puck_200727_02
# 31                                  Myeloid cells of human eye
# 40                                                         PNS
# 51           Stellate cells from human healthy donor liver ...
# 75           Urethral luminal epithelia are castration-inse...
# 97           A single-cell and spatially-resolved atlas of ...
# 106                                              ClassPlacodes
# 114                                      UMAP of Myeloid cells
# 153          Aorta — A single-cell transcriptomic atlas cha...
# 179          spRNA-seq for GZMK+CD8+ T cells Target A Speci...
# 214          Single cell transcriptome analysis of human pa...
# 235                                 e12.5 thalamic progenitors
# 246                                         Gland Immune Atlas
# 254          SstChodl - neocortex: Human variation study (HVS)
# 262           Infiltrating Neoplastic Cells Human Glioblastoma
# 275          Supercluster: Committed oligodendrocyte precursor
# 280                       DCM/ACM heart cell atlas: Adipocytes
# 304                   Mature kidney dataset: non PT parenchyma
#
#                     issue_type
# soma_joinid
# 9                     no_pmcid
# 21                    no_title
# 26                    no_title
# 31                    no_pmcid
# 40                    no_pmcid
# 51                    no_pmcid
# 75                    no_title
# 97                    no_title
# 106                   no_pmcid
# 114                   no_pmcid
# 153                   no_title
# 179          no_method_headers
# 214                   no_title
# 235                   no_pmcid
# 246                   no_title
# 254                   no_title
# 262                   no_title
# 275                   no_pmcid
# 280          no_method_headers
# 304                   no_title
